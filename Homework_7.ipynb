# %% [markdown]
# <a href="https://colab.research.google.com/github/kaashcro/MAT421-ComputationalMethods/blob/main/Homework_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Numerical Differentiation Problem Statement
#
# Differentiation is taking the derivative of an equation df/dt= (f(t)+f(t+e))/e where e is a small number. When it is numerical differentiation we can make a grid of evenly spaced intervals for e.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Finite Difference Approximating Derivatives
#
# finite derifatives is when you take the diffrence manually and in steps, it can be approximated as f'(a)=lim(x to a)(f(x)-f(a)/(x-a))

# %%
# step size
h = 0.1
# define grid
x = np.arange(0, 2*np.pi, h)
# compute function
y = np.cos(x) + np.sin(x)
# compute vector of forward differences
forward_diff = np.diff(y)/h
# compute corresponding grid
x_diff = x[:-1:]
# compute exact solution
exact_solution = -np.sin(x_diff) + np.cos(x_diff)
# Plot solution
plt.figure(figsize = (12, 8))
plt.plot(x_diff, forward_diff, '--', \
 label = 'Finite difference approximation')
plt.plot(x_diff, exact_solution, \
 label = 'Exact solution')
plt.legend()
plt.show()
# Compute max error between
# numerical derivative and exact solution
max_error = max(abs(exact_solution - forward_diff))
print(max_error)
# Out:
# 0.07068961714190192

# %%
# define step size
h = 1
# define number of iterations to perform
iterations = 20
# list to store our step sizes
step_size = []
# list to store max error for each step size
max_error = []
for i in range(iterations):
 # halve the step size
 h /= 2
 # store this step size
 step_size.append(h)
 # compute new grid
 x = np.arange(0, 2 * np.pi, h)
 # compute function value at grid
 y = np.cos(x)
 # compute vector of forward differences
 forward_diff = np.diff(y)/h
 # compute corresponding grid
 x_diff = x[:-1]
 # compute exact solution
 exact_solution = -np.sin(x_diff)

 # Compute max error between
 # numerical derivative and exact solution
 max_error.append(\
 max(abs(exact_solution - forward_diff)))
# produce log-log plot of max error versus step size
plt.figure(figsize = (12, 8))
plt.loglog(step_size, max_error, 'v')
plt.show()

# %% [markdown]
# Approximating of Higher Order Derivatives
#
# It is also possible to use the Taylor series to approximate higher-order derivatives
